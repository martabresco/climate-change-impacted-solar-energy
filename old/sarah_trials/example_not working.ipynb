# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import atlite
import numpy as np
import logging 
logging.basicConfig(level=logging.INFO)

# %%
ds=xr.open_dataset("/groups/EXTREMES/SARAH-3/2014/SISin201412310000004UD1000101UD.nc")
ds
# Out:
# <xarray.Dataset> Size: 277MB
# Dimensions:        (time: 48, lon: 1600, bnds: 2, lat: 900)
# Coordinates:
#   * time           (time) datetime64[ns] 384B 2014-12-31 ... 2014-12-31T23:30:00
#   * lon            (lon) float32 6kB -29.98 -29.92 -29.88 ... 49.88 49.92 49.97
#   * lat            (lat) float32 4kB 20.02 20.08 20.12 ... 64.88 64.93 64.97
# Dimensions without coordinates: bnds
# Data variables:
#     lon_bnds       (lon, bnds) float32 13kB ...
#     lat_bnds       (lat, bnds) float32 7kB ...
#     SIS            (time, lat, lon) float32 276MB ...
#     record_status  (time) int8 48B ...
# Attributes: (12/41)
#     CDI:                        Climate Data Interface version 2.4.0 (https:/...
#     Conventions:                CF-1.7,ACDD-1.3
#     institution:                EUMETSAT/CMSAF
#     id:                         DOI:10.5676/EUM_SAF_CM/SARAH/V003
#     product_version:            3.0
#     creator_name:               DE/DWD
#     ...                         ...
#     variable_id:                SIS
#     license:                    The CM SAF data are owned by EUMETSAT and are...
#     title:                      CM SAF Surface Solar Radiation Climate Data R...
#     summary:                    This file contains data from the CM SAF Surfa...
#     history:                    Wed Mar 05 14:29:03 2025: cdo -v -L -f nc4 -z...
#     CDO:                        Climate Data Operators version 2.4.0 (https:/...

# %%
start_date="2014-01-01"
end_date="2014-01-02"
cutout_2014 = atlite.Cutout(
    path="europe_2014_01",
    module=["sarah", "era5"],
    sarah_dir="Sarah_data_2014_v4", #change directory
    x=slice(-13.6913, 1.7712),
    y=slice(49.9096, 60.8479),
    time=slice(start_date, end_date),
    #time="2014-01",
   #chunks={"time": 100},
)
# Out:
# INFO:atlite.cutout:Building new cutout europe_2014_01.nc

# %%
cutout_2014.prepare()
# Out:
# INFO:atlite.data:Storing temporary files in /tmp/tmph53_jm8y
# INFO:atlite.data:Calculating and writing with module sarah:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cutout_2014.prepare()
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/data.py:115, in maybe_remove_tmpdir.<locals>.wrapper(*args, **kwargs)
#     113 kwargs["tmpdir"] = mkdtemp()
#     114 try:
# --> 115     res = func(*args, **kwargs)
#     116 finally:
#     117     rmtree(kwargs["tmpdir"])
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/data.py:208, in cutout_prepare(cutout, features, tmpdir, overwrite, compression, show_progress, dask_kwargs, monthly_requests, concurrent_requests)
#     206 logger.info(f"Calculating and writing with module {module}:")
#     207 missing_features = missing_vars.index.unique("feature")
# --> 208 ds = get_features(
#     209     cutout,
#     210     module,
#     211     missing_features,
#     212     tmpdir=tmpdir,
#     213     monthly_requests=monthly_requests,
#     214     concurrent_requests=concurrent_requests,
#     215 )
#     216 prepared |= set(missing_features)
#     218 cutout.data.attrs.update(dict(prepared_features=list(prepared)))
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/data.py:57, in get_features(cutout, module, features, tmpdir, monthly_requests, concurrent_requests)
#      46     feature_data = delayed(get_data)(
#      47         cutout,
#      48         feature,
#    (...)
#      53         **parameters,
#      54     )
#      55     datasets.append(feature_data)
# ---> 57 datasets = compute(*datasets)
#      59 ds = xr.merge(datasets, compat="equals")
#      60 for v in ds:
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/datasets/sarah.py:227, in get_data(cutout, feature, tmpdir, lock, monthly_requests, **creation_parameters)
#     224     ds = hourly_mean(ds)
#     226 if (cutout.dx != dx) or (cutout.dy != dy):
# --> 227     ds = regrid(ds, coords["lon"], coords["lat"], resampling=Resampling.average)
#     229 dif_attrs = dict(long_name="Surface Diffuse Shortwave Flux", units="W m-2")
#     230 ds["influx_diffuse"] = (ds["SIS"] - ds["SID"]).assign_attrs(**dif_attrs)
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/atlite/gis.py:846, in regrid(ds, dimx, dimy, **kwargs)
#     842 dtypes = {da.dtype for da in data_vars}
#     843 assert len(dtypes) == 1, "regrid can only reproject datasets with homogeneous dtype"
#     845 return (
# --> 846     xr.apply_ufunc(
#     847         _reproject,
#     848         ds,
#     849         input_core_dims=[[namey, namex]],
#     850         output_core_dims=[["yout", "xout"]],
#     851         output_dtypes=[dtypes.pop()],
#     852         dask_gufunc_kwargs=dict(
#     853             output_sizes={"yout": dst_shape[0], "xout": dst_shape[1]}
#     854         ),
#     855         dask="parallelized",
#     856         kwargs=kwargs,
#     857     )
#     858     .rename({"yout": namey, "xout": namex})
#     859     .assign_coords(
#     860         **{
#     861             namey: (namey, dimy.data, ds.coords[namey].attrs),
#     862             namex: (namex, dimx.data, ds.coords[namex].attrs),
#     863         }
#     864     )
#     865     .assign_attrs(**ds.attrs)
#     866 )
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/xarray/core/computation.py:1258, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1256 # feed datasets apply_variable_ufunc through apply_dataset_vfunc
#    1257 elif any(is_dict_like(a) for a in args):
# -> 1258     return apply_dataset_vfunc(
#    1259         variables_vfunc,
#    1260         *args,
#    1261         signature=signature,
#    1262         join=join,
#    1263         exclude_dims=exclude_dims,
#    1264         dataset_join=dataset_join,
#    1265         fill_value=dataset_fill_value,
#    1266         keep_attrs=keep_attrs,
#    1267         on_missing_core_dim=on_missing_core_dim,
#    1268     )
#    1269 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1270 elif any(isinstance(a, DataArray) for a in args):
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/xarray/core/computation.py:529, in apply_dataset_vfunc(func, signature, join, dataset_join, fill_value, exclude_dims, keep_attrs, on_missing_core_dim, *args)
#     524 list_of_coords, list_of_indexes = build_output_coords_and_indexes(
#     525     args, signature, exclude_dims, combine_attrs=keep_attrs
#     526 )
#     527 args = tuple(getattr(arg, "data_vars", arg) for arg in args)
# --> 529 result_vars = apply_dict_of_variables_vfunc(
#     530     func,
#     531     *args,
#     532     signature=signature,
#     533     join=dataset_join,
#     534     fill_value=fill_value,
#     535     on_missing_core_dim=on_missing_core_dim,
#     536 )
#     538 out: Dataset | tuple[Dataset, ...]
#     539 if signature.num_outputs > 1:
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/xarray/core/computation.py:453, in apply_dict_of_variables_vfunc(func, signature, join, fill_value, on_missing_core_dim, *args)
#     451 core_dim_present = _check_core_dims(signature, variable_args, name)
#     452 if core_dim_present is True:
# --> 453     result_vars[name] = func(*variable_args)
#     454 else:
#     455     if on_missing_core_dim == "raise":
#
# File ~/anaconda3/envs/atlite_cmip6_2025/lib/python3.13/site-packages/xarray/core/computation.py:770, in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     768             for axis, dim in enumerate(core_dims, start=-len(core_dims)):
#     769                 if len(data.chunks[axis]) != 1:
# --> 770                     raise ValueError(
#     771                         f"dimension {dim} on {n}th function argument to "
#     772                         "apply_ufunc with dask='parallelized' consists of "
#     773                         "multiple chunks, but is also a core dimension. To "
#     774                         "fix, either rechunk into a single array chunk along "
#     775                         f"this dimension, i.e., ``.chunk(dict({dim}=-1))``, or "
#     776                         "pass ``allow_rechunk=True`` in ``dask_gufunc_kwargs`` "
#     777                         "but beware that this may significantly increase memory usage."
#     778                     )
#     779     dask_gufunc_kwargs["allow_rechunk"] = True
#     781 output_sizes = dask_gufunc_kwargs.pop("output_sizes", {})
#
# ValueError: dimension lat on 0th function argument to apply_ufunc with dask='parallelized' consists of multiple chunks, but is also a core dimension. To fix, either rechunk into a single array chunk along this dimension, i.e., ``.chunk(dict(lat=-1))``, or pass ``allow_rechunk=True`` in ``dask_gufunc_kwargs`` but beware that this may significantly increase memory usage.
