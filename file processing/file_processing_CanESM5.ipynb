# %%
import sys
import xarray as xr
import numpy as np
from datetime import timedelta
from glob import glob
import cftime
from future_wind_copy import combine_hemispheres 
from datetime import timedelta
from datetime import datetime

# %%
def combine_hemispheres(var,time=None,lev=None,for_interp=False, 
    reverse_lev=False, 
    minlat=20.,maxlat=75.,minlon=330.,maxlon=50.):  
    '''Combine array (var) from both hemispheres with continuous
    coordinates.
    In some datasets the vertical coordinate is reversed.'''

    min_lat = minlat ; max_lat = maxlat
    min_lon = minlon ; max_lon = maxlon

    # print(lev)

    if (for_interp):
        min_lat = minlat - 5. ; max_lat = maxlat + 5.
        min_lon = minlon - 5. ; max_lon = maxlon + 5.

    if time is None and lev is None:
        west = var.sel(lat=slice(min_lat,max_lat),lon=slice(min_lon,360.))
        west['lon'] = west['lon'] - 360.
        east = var.sel(lat=slice(min_lat,max_lat),lon=slice(0.,max_lon))

    elif lev is None:
        west = var.sel(lat=slice(min_lat,max_lat),lon=slice(min_lon,360.),
                       time=time)
        west['lon'] = west['lon'] - 360.
        east = var.sel(lat=slice(min_lat,max_lat),lon=slice(0.,max_lon),
                       time=time)
        
    elif isinstance(lev,int) and lev==0:
        west = var.sel(lat=slice(min_lat,max_lat),lon=slice(min_lon,360.),
                       time=time).isel(lev=0)
        west['lon'] = west['lon'] - 360.
        east = var.sel(lat=slice(min_lat,max_lat),lon=slice(0.,max_lon),
                       time=time).isel(lev=0)

    else:   ##isinstance(lev,slice) or isinstance(lev,np.ndarray):
        west = var.sel(lat=slice(min_lat,max_lat),lon=slice(min_lon,360.),
                       lev=lev,time=time)
        west['lon'] = west['lon'] - 360.
        east = var.sel(lat=slice(min_lat,max_lat),lon=slice(0.,max_lon),
                       lev=lev,time=time)
        
    west_east = xr.concat([west,east],'lon')

    if (reverse_lev):
        west_east = west_east.reindex(lev=west_east.lev[::-1])

    return west_east

# %%
def cut_europe_and_interpolate(ds_rsds,ds_rsdsdiff,ds_tas):
    ds_rsds_europe = combine_hemispheres(ds_rsds,minlat=20.,maxlat=75.,minlon=330.,maxlon=50.)
    ds_rsdsdiff_europe = combine_hemispheres(ds_rsdsdiff,minlat=20.,maxlat=75.,minlon=330.,maxlon=50.)    
    ds_tas_europe = combine_hemispheres(ds_tas,minlat=20.,maxlat=75.,minlon=330.,maxlon=50.) 

    # Interpolate tas to match rsds time
    tas_interp= ds_tas_europe['tas'].interp(time=ds_rsds_europe['time'], method="linear")
    # Create a mask for the NaN values using .isnull()
    nan_mask = tas_interp.isnull()

    # For each time step, replace NaNs with the values from the next time step
    for t in range(len(tas_interp.time) - 1):  # Exclude the last time step
        #Use .isel() to ensure the correct alignment of coordinates
        tas_interp[t] = tas_interp[t].where(~nan_mask[t], tas_interp.isel(time=t + 1))
    
    ds_tas_europe['time'] = ds_rsds_europe['time']
    ds_tas_europe['tas'] = tas_interp


    return ds_rsds_europe, ds_rsdsdiff_europe, ds_tas_europe, tas_interp

# %%
def make_data_set(du,rsds,rsdsdiff,tas):
    """Creates xarray DataArray for netCDF write
    Args:
        du (dataset): sample dataset with attributes
        rsds (DataArray): wind speed 
        rsdsdiff (DataArray): wind direction
        tas (DataArray): surface air density

    Returns:
        xarray DataArray: DataArray for write
    """
    lat = xr.DataArray(
        data=rsds.lat.values.astype('float32'),
        dims=["lat"],
        coords=dict(
            lat=(["lat"], rsds.lat.values)
        ),
        attrs=dict(
        long_name="latitude",
        units="degrees_north",
        axis="Y"
        ),
    )
    lon = xr.DataArray(
        data=rsds.lon.values.astype('float32'),
        dims="lon",
        coords=dict(
            lon=(["lon"], rsds.lon.values)
        ),
        attrs=dict(
        long_name="longitude",
        units="degrees_east",
        axis="X"
        ),
    )
    
    ds = xr.Dataset(
        data_vars=dict(
            rsds = (
                ["time","lat","lon"],rsds.values.astype('float32'),
                dict(long_name = "rsds",
                units = "W/m2")),
            rsdsdiff = (
                ["time","lat","lon"],rsdsdiff.values.astype('float32'),
                dict(long_name = "rsdsdiff",
                units = "W/m2",
                vert_units = "W/m2")),
            tas = (
                ["time","lat","lon"],tas.values.astype('float32'),
                dict(long_name = "surface air density",
                units = "K",
                height = "surface")),
            ),
        coords=dict(
            lon=lon,
            lat=lat,
            time=rsds.time
            ),
        attrs=dict(
            data_source = "Processed data from CMIP6 runs",
            experiment = du.experiment_id,
            source = du.source_id,
            variant_label = du.variant_label,
            data_written = datetime.now().strftime("%d/%m/%Y %H:%M")
            )
    )   
    return ds

# %%
import os
import re
import xarray as xr
from collections import defaultdict
from datetime import datetime
import numpy as np

# Folder containing the files
folder_path = "/groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/" #remember to change

# Regex to extract the period (last two date segments)
pattern = re.compile(r"(\d{12})-(\d{12})\.nc$")

# Organizing files by type and period
file_dict = defaultdict(list)

# List all netCDF files
for filename in os.listdir(folder_path):
    match = pattern.search(filename)
    if match:
        start, end = match.groups()
        start_dt = datetime.strptime(start, "%Y%m%d%H%M")
        end_dt = datetime.strptime(end, "%Y%m%d%H%M")

        # Determine file type and append to the dictionary
        if "tas" in filename:
            file_dict["tas"].append((start_dt, end_dt, filename))
        elif "rsds_" in filename:  # Avoid matching "rsdsdiff"
            file_dict["rsds"].append((start_dt, end_dt, filename))
        elif "rsdsdiff" in filename:
            file_dict["rsdsdiff"].append((start_dt, end_dt, filename))

# Function to find overlapping periods
def find_overlaps(list1, list2):
    overlaps = []
    for start1, end1, file1 in list1:
        for start2, end2, file2 in list2:
            # Check if periods overlap
            if start1 <= end2 and start2 <= end1:
                # Determine the overlapping period
                overlap_start = max(start1, start2)
                overlap_end = min(end1, end2)
                overlaps.append((overlap_start, overlap_end, file1, file2))
    return overlaps

# Find overlapping periods between tas and rsds files
tas_rsds_overlaps = find_overlaps(file_dict["tas"], file_dict["rsds"])

# Find overlapping periods between the overlaps above and rsdsdiff files
final_overlaps = []
for overlap_start, overlap_end, tas_file, rsds_file in tas_rsds_overlaps:
    for start3, end3, rsdsdiff_file in file_dict["rsdsdiff"]:
        if overlap_start <= end3 and start3 <= overlap_end:
            final_start = max(overlap_start, start3)
            final_end = min(overlap_end, end3)
            final_overlaps.append((final_start, final_end, tas_file, rsds_file, rsdsdiff_file))
print(final_overlaps)

# Process each set of overlapping files
for overlap_start, overlap_end, tas_file, rsds_file, rsdsdiff_file in final_overlaps:
    print(f"Processing overlap from {overlap_start} to {overlap_end}:")
    print(f"  - TAS file: {tas_file}")
    print(f"  - RSDS file: {rsds_file}")
    print(f"  - RSDSDIFF file: {rsdsdiff_file}")

    # Open datasets
    tas_ds = xr.open_dataset(os.path.join(folder_path, tas_file))
    rsds_ds = xr.open_dataset(os.path.join(folder_path, rsds_file))
    rsdsdiff_ds = xr.open_dataset(os.path.join(folder_path, rsdsdiff_file))

    # Apply the first function: cut and interpolate
    ds_rsds_europe, ds_rsdsdiff_europe, ds_tas_europe, tas_interp = cut_europe_and_interpolate(
        rsds_ds, rsdsdiff_ds, tas_ds
    )
    rsds_data = ds_rsds_europe['rsds']
    rsdsdiff_data = ds_rsdsdiff_europe['rsdsdiff']
    tas_data = ds_tas_europe['tas']
    ds = make_data_set(rsds_ds, rsds_data, rsdsdiff_data, tas_data)

    # Ensure combined_dataset is defined and has a 'time' dimension
    if 'time' in ds.dims:
        unique_years = np.unique(ds.time.dt.year.values)

        for year in unique_years:
            # Generate the file path for the output file
            output_file = f"/groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_{year}.nc"
            
            # Check if the file already exists
            if not os.path.exists(output_file):
                # Extract data for this year using slicing
                yearly_data = ds.sel(time=slice(f"{year}-01-01", f"{year}-12-31"))

                # Check if yearly_data is not empty
                if yearly_data.time.size > 0:
                    # Save as .nc file
                    yearly_data.to_netcdf(output_file)
                    print(f"Saved data for year {year} to {output_file}")
                else:
                    print(f"No data available for the year {year}")
            else:
                print(f"File for year {year} already exists, skipping.")
    else:
        print("The dataset does not contain a 'time' dimension.")

    # Close datasets
    tas_ds.close()
    rsds_ds.close()
    rsdsdiff_ds.close()
    # ds.close()

print("Processing complete.")
# Out:
# [(datetime.datetime(2051, 1, 1, 3, 0), datetime.datetime(2060, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_205101010300-206101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_205101010130-206012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_205101010130-206012312230.nc'), (datetime.datetime(2071, 1, 1, 3, 0), datetime.datetime(2080, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_207101010300-208101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_207101010130-208012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_207101010130-208012312230.nc'), (datetime.datetime(2021, 1, 1, 3, 0), datetime.datetime(2030, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_202101010300-203101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_202101010130-203012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_202101010130-203012312230.nc'), (datetime.datetime(2091, 1, 1, 3, 0), datetime.datetime(2100, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_209101010300-210101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_209101010130-210012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_209101010130-210012312230.nc'), (datetime.datetime(2015, 1, 1, 3, 0), datetime.datetime(2020, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_201501010300-202101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_201501010130-202012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_201501010130-202012312230.nc'), (datetime.datetime(2041, 1, 1, 3, 0), datetime.datetime(2050, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_204101010300-205101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_204101010130-205012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_204101010130-205012312230.nc'), (datetime.datetime(2061, 1, 1, 3, 0), datetime.datetime(2070, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_206101010300-207101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_206101010130-207012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_206101010130-207012312230.nc'), (datetime.datetime(2081, 1, 1, 3, 0), datetime.datetime(2090, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_208101010300-209101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_208101010130-209012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_208101010130-209012312230.nc'), (datetime.datetime(2031, 1, 1, 3, 0), datetime.datetime(2040, 12, 31, 22, 30), 'tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_203101010300-204101010000.nc', 'rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_203101010130-204012312230.nc', 'rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_203101010130-204012312230.nc')]
# Processing overlap from 2051-01-01 03:00:00 to 2060-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_205101010300-206101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_205101010130-206012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_205101010130-206012312230.nc
# Saved data for year 2051 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2051.nc
# Saved data for year 2052 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2052.nc
# Saved data for year 2053 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2053.nc
# Saved data for year 2054 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2054.nc
# Saved data for year 2055 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2055.nc
# Saved data for year 2056 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2056.nc
# Saved data for year 2057 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2057.nc
# Saved data for year 2058 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2058.nc
# Saved data for year 2059 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2059.nc
# Saved data for year 2060 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2060.nc
# Processing overlap from 2071-01-01 03:00:00 to 2080-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_207101010300-208101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_207101010130-208012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_207101010130-208012312230.nc
# Saved data for year 2071 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2071.nc
# Saved data for year 2072 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2072.nc
# Saved data for year 2073 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2073.nc
# Saved data for year 2074 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2074.nc
# Saved data for year 2075 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2075.nc
# Saved data for year 2076 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2076.nc
# Saved data for year 2077 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2077.nc
# Saved data for year 2078 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2078.nc
# Saved data for year 2079 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2079.nc
# Saved data for year 2080 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2080.nc
# Processing overlap from 2021-01-01 03:00:00 to 2030-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_202101010300-203101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_202101010130-203012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_202101010130-203012312230.nc
# Saved data for year 2021 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2021.nc
# Saved data for year 2022 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2022.nc
# Saved data for year 2023 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2023.nc
# Saved data for year 2024 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2024.nc
# Saved data for year 2025 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2025.nc
# Saved data for year 2026 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2026.nc
# Saved data for year 2027 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2027.nc
# Saved data for year 2028 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2028.nc
# Saved data for year 2029 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2029.nc
# Saved data for year 2030 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2030.nc
# Processing overlap from 2091-01-01 03:00:00 to 2100-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_209101010300-210101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_209101010130-210012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_209101010130-210012312230.nc
# Saved data for year 2091 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2091.nc
# Saved data for year 2092 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2092.nc
# Saved data for year 2093 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2093.nc
# Saved data for year 2094 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2094.nc
# Saved data for year 2095 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2095.nc
# Saved data for year 2096 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2096.nc
# Saved data for year 2097 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2097.nc
# Saved data for year 2098 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2098.nc
# Saved data for year 2099 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2099.nc
# Saved data for year 2100 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2100.nc
# Processing overlap from 2015-01-01 03:00:00 to 2020-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_201501010300-202101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_201501010130-202012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_201501010130-202012312230.nc
# Saved data for year 2015 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2015.nc
# Saved data for year 2016 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2016.nc
# Saved data for year 2017 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2017.nc
# Saved data for year 2018 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2018.nc
# Saved data for year 2019 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2019.nc
# Saved data for year 2020 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2020.nc
# Processing overlap from 2041-01-01 03:00:00 to 2050-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_204101010300-205101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_204101010130-205012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_204101010130-205012312230.nc
# Saved data for year 2041 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2041.nc
# Saved data for year 2042 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2042.nc
# Saved data for year 2043 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2043.nc
# Saved data for year 2044 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2044.nc
# Saved data for year 2045 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2045.nc
# Saved data for year 2046 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2046.nc
# Saved data for year 2047 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2047.nc
# Saved data for year 2048 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2048.nc
# Saved data for year 2049 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2049.nc
# Saved data for year 2050 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2050.nc
# Processing overlap from 2061-01-01 03:00:00 to 2070-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_206101010300-207101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_206101010130-207012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_206101010130-207012312230.nc
# Saved data for year 2061 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2061.nc
# Saved data for year 2062 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2062.nc
# Saved data for year 2063 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2063.nc
# Saved data for year 2064 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2064.nc
# Saved data for year 2065 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2065.nc
# Saved data for year 2066 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2066.nc
# Saved data for year 2067 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2067.nc
# Saved data for year 2068 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2068.nc
# Saved data for year 2069 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2069.nc
# Saved data for year 2070 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2070.nc
# Processing overlap from 2081-01-01 03:00:00 to 2090-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_208101010300-209101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_208101010130-209012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_208101010130-209012312230.nc
# Saved data for year 2081 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2081.nc
# Saved data for year 2082 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2082.nc
# Saved data for year 2083 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2083.nc
# Saved data for year 2084 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2084.nc
# Saved data for year 2085 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2085.nc
# Saved data for year 2086 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2086.nc
# Saved data for year 2087 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2087.nc
# Saved data for year 2088 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2088.nc
# Saved data for year 2089 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2089.nc
# Saved data for year 2090 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2090.nc
# Processing overlap from 2031-01-01 03:00:00 to 2040-12-31 22:30:00:
#   - TAS file: tas_3hr_CanESM5_ssp585_r1i1p2f1_gn_203101010300-204101010000.nc
#   - RSDS file: rsds_3hr_CanESM5_ssp585_r1i1p2f1_gn_203101010130-204012312230.nc
#   - RSDSDIFF file: rsdsdiff_3hr_CanESM5_ssp585_r1i1p2f1_gn_203101010130-204012312230.nc
# Saved data for year 2031 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2031.nc
# Saved data for year 2032 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2032.nc
# Saved data for year 2033 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2033.nc
# Saved data for year 2034 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2034.nc
# Saved data for year 2035 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2035.nc
# Saved data for year 2036 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2036.nc
# Saved data for year 2037 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2037.nc
# Saved data for year 2038 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2038.nc
# Saved data for year 2039 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2039.nc
# Saved data for year 2040 to /groups/FutureWind/SFCRAD/CanESM5/ssp585/r1i1p2f1/rsds_rsdsdiff_tas_2040.nc
# Processing complete.
